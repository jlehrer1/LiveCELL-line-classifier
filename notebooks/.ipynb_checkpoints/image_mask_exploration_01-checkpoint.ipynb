# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os, pathlib 
import json
import PIL
from IPython.display import Image

# %%
with open('../images/train.json', 'r') as f:
    contents = json.loads(f.read())

# %%
contents['annotations']
# Out:
# [{'id': 2,
#   'image_id': 1,
#   'category_id': 1,
#   'segmentation': [[288.02,
#     305.63,
#     286.01,
#     298.87,
#     286.01,
#     295.4,
#     288.02,
#     290.1,
#     293.86,
#     287.91,
#     297.51,
#     287.73,
#     300.44,
#     289.01,
#     304.27,
#     292.48,
#     304.64,
#     295.04,
#     305.18,
#     297.77,
#     305.18,
#     300.7,
#     303.91,
#     302.52,
#     301.17,
#     305.26,
#     297.33,
#     307.45,
#     294.59,
#     307.45,
#     290.58,
#     308.0]],
#   'area': 307.4786000000313,
#   'bbox': [286.01, 287.73, 19.170000000000016, 20.269999999999982],
#   'iscrowd': 0},
#  {'id': 3,
#   'image_id': 1,
#   'category_id': 1,
#   'segmentation': [[271.22,
#     323.34,
#     267.93,
#     322.61,
#     266.29,
#     320.6,
#     265.38,
#     316.95,
#     263.37,
#     311.47,
#     263.0,
#     308.18,
#     265.19,
#     305.99,
#     267.93,
#     305.44,
#     270.31,
#     304.9,
#     274.32,
#     307.45,
#     275.42,
# ...

# %%
f = contents['images'][0]
f['file_name']
# Out:
# 'BT474_Phase_A3_2_00d04h00m_3.tif'

# %%
img = Image.open(f"../images/BT474/{name}")
display(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/pd/jsjcl0fn7w57s5mfr34b20pm0000gn/T/ipykernel_73850/3068524556.py in <module>
# ----> 1 img = Image.open(f"../images/BT474/{name}")
#       2 display(img)
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
contents['annotations']
# Out:
# [{'id': 2,
#   'image_id': 1,
#   'category_id': 1,
#   'segmentation': [[288.02,
#     305.63,
#     286.01,
#     298.87,
#     286.01,
#     295.4,
#     288.02,
#     290.1,
#     293.86,
#     287.91,
#     297.51,
#     287.73,
#     300.44,
#     289.01,
#     304.27,
#     292.48,
#     304.64,
#     295.04,
#     305.18,
#     297.77,
#     305.18,
#     300.7,
#     303.91,
#     302.52,
#     301.17,
#     305.26,
#     297.33,
#     307.45,
#     294.59,
#     307.45,
#     290.58,
#     308.0]],
#   'area': 307.4786000000313,
#   'bbox': [286.01, 287.73, 19.170000000000016, 20.269999999999982],
#   'iscrowd': 0},
#  {'id': 3,
#   'image_id': 1,
#   'category_id': 1,
#   'segmentation': [[271.22,
#     323.34,
#     267.93,
#     322.61,
#     266.29,
#     320.6,
#     265.38,
#     316.95,
#     263.37,
#     311.47,
#     263.0,
#     308.18,
#     265.19,
#     305.99,
#     267.93,
#     305.44,
#     270.31,
#     304.9,
#     274.32,
#     307.45,
#     275.42,
# ...
